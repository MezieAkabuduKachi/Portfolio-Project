# %% [markdown]
# # CARS DATASET

# %% [markdown]
# ## Here, The data of different cars by the specifications.

# %% [markdown]
# ### Importing Libraries needed for the analysis.

# %%
import pandas as pd

# %% [markdown]
# ### Importing the Cars Dataset.

# %%
car = pd.read_csv(r'C:\Users\PC\Downloads\2. Cars Data1.csv')

# %% [markdown]
# ### Showing the Car Dataset.

# %%
car
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ### Showing the number of rows and columns in the Cars Dataset.

# %%
car.shape
# Out:
# (432, 15)

# %% [markdown]
# ### Showing the first 5 rows of the Cars Dataset.

# %%
car.head(5)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %% [markdown]
# ### Showing the data types of each column.

# %%
car.dtypes
# Out:
# Make            object
# Model           object
# Type            object
# Origin          object
# DriveTrain      object
# MSRP            object
# Invoice         object
# EngineSize     float64
# Cylinders      float64
# Horsepower     float64
# MPG_City       float64
# MPG_Highway    float64
# Weight         float64
# Wheelbase      float64
# Length         float64
# dtype: object

# %% [markdown]
# ### For Data Cleaning purpose: Find all Null values in the dataset. If there are any Null values in any columns, Fill it with the Mean of that column.

# %% [markdown]
# ### So this is basically the first part of the question, Which is Finding the Null values in the dataset if any?

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %% [markdown]
# ## Filling the Null values with the Mean of its column.

# %% [markdown]
# ### Note: In the above output where there are null values in the columns like "Make, Model, Type, Origin, DriveTrain, MSRP, Invoice". They can not be filled up with the Mean of their various columns because they are not Numeric Values, as you can see above in the data types of the columns, they are objects and objects are not numeric. Therefore can not apply Mean to them.

# %%
car['EngineSize'].fillna(car['EngineSize'].mean(), inplace = True)
car['Cylinders'].fillna(car['Cylinders'].mean(), inplace = True)
car['Horsepower'].fillna(car['Horsepower'].mean(), inplace = True)
car['MPG_City'].fillna(car['MPG_City'].mean(), inplace = True)
car['MPG_Highway'].fillna(car['MPG_Highway'].mean(), inplace = True)
car['Weight'].fillna(car['Weight'].mean(), inplace = True)
car['Wheelbase'].fillna(car['Wheelbase'].mean(), inplace = True)
car['Length'].fillna(car['Length'].mean(), inplace = True)

# %% [markdown]
# ### Now you can notice the difference, all the Null values with Numeric columns(float64 datatype) have been replaced.

# %%
car.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     0
# Cylinders      0
# Horsepower     0
# MPG_City       0
# MPG_Highway    0
# Weight         0
# Wheelbase      0
# Length         0
# dtype: int64

# %% [markdown]
# ## Checking what are the different types of "Make" in the dataset. And . What the count(occurence) of each "Make" in the data is.

# %% [markdown]
# ### Note: The count of each type of "Make" is shown beside each "Make".

# %%
car['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Volvo            12
# Jaguar           12
# Hyundai          12
# Subaru           11
# Pontiac          11
# Mazda            11
# Lexus            11
# Kia              11
# Buick             9
# Mercury           9
# Lincoln           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
car.head(2)
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0

# %% [markdown]
# ### Showing all Records where "Origin" is Asia or Europe.

# %%
car[car['Origin'].isin(['Asia', 'Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## REMOVING UNWANTED RECORDS.

# %% [markdown]
# ### Removing all Records(rows) where "Weight" is above 4000.

# %%
car[~(car['Weight'] > 4000)]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %% [markdown]
# ## APPLYING A FUNCTION ON A COLUMN.

# %% [markdown]
# ### Increasing the values of 'MPG_City' column by 3.

# %%
car['MPG_City'] = car['MPG_City'].apply(lambda x:x+3)

# %% [markdown]
# ### Showing previous 'MPG_City' Column.

# %%
car.head(20)
# Out:
#      Make                           Model    Type  Origin DriveTrain  \
# 0   Acura                             MDX     SUV    Asia        All
# 1   Acura                  RSX Type S 2dr   Sedan    Asia      Front
# 2   Acura                         TSX 4dr   Sedan    Asia      Front
# 3   Acura                          TL 4dr   Sedan    Asia      Front
# 4   Acura                      3.5 RL 4dr   Sedan    Asia      Front
# 5   Acura         3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6   Acura          NSX coupe 2dr manual S  Sports    Asia       Rear
# 7    Audi                     A4 1.8T 4dr   Sedan  Europe      Front
# 8    Audi          A41.8T convertible 2dr   Sedan  Europe      Front
# 9    Audi                      A4 3.0 4dr   Sedan  Europe      Front
# 10   Audi       A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11   Audi         A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# 12   Audi                      A6 3.0 4dr   Sedan  Europe      Front
# ...

# %% [markdown]
# ### Showing New 'MPG_City' Column.

# %%
car.head(20)
# Out:
#      Make                           Model    Type  Origin DriveTrain  \
# 0   Acura                             MDX     SUV    Asia        All
# 1   Acura                  RSX Type S 2dr   Sedan    Asia      Front
# 2   Acura                         TSX 4dr   Sedan    Asia      Front
# 3   Acura                          TL 4dr   Sedan    Asia      Front
# 4   Acura                      3.5 RL 4dr   Sedan    Asia      Front
# 5   Acura         3.5 RL w/Navigation 4dr   Sedan    Asia      Front
# 6   Acura          NSX coupe 2dr manual S  Sports    Asia       Rear
# 7    Audi                     A4 1.8T 4dr   Sedan  Europe      Front
# 8    Audi          A41.8T convertible 2dr   Sedan  Europe      Front
# 9    Audi                      A4 3.0 4dr   Sedan  Europe      Front
# 10   Audi       A4 3.0 Quattro 4dr manual   Sedan  Europe        All
# 11   Audi         A4 3.0 Quattro 4dr auto   Sedan  Europe        All
# 12   Audi                      A6 3.0 4dr   Sedan  Europe      Front
# ...
